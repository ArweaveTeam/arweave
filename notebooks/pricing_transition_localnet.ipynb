# %% [markdown]
# # Test pricing transition on localnet
#
# This notebook connects to a running localnet node, inspects pricing transition behavior,
# and compares current vs scheduled prices around transition end.

# %% [markdown]
# ## Configure connection

# %%
Cookie = 'localnet',
Node = 'main-localnet@127.0.0.1',

HostHasDot =
    case string:split(atom_to_list(node()), "@") of
        [_Name, Host] ->
            case string:find(Host, ".") of
                nomatch ->
                    false;
                _ ->
                    true
            end;
        _ ->
            false
    end,

_ =
    case {node(), HostHasDot} of
        {nonode@nohost, _} ->
            net_kernel:start([list_to_atom("pricing_notebook@127.0.0.1"), longnames]);
        {_, true} ->
            ok;
        {_, false} ->
            net_kernel:stop(),
            net_kernel:start([list_to_atom("pricing_notebook@127.0.0.1"), longnames])
    end,

erlang:set_cookie(node(), Cookie).
# Out:
# true

# %%
%% RPC helpers and record accessors
%% The ierl kernel does not provide rr/c:rr, so compile a tiny accessor module.
AccessorModule =
    lists:flatten([
        "-module(nb_block_accessors).\n",
        "-export([price_per_gib_minute/1, scheduled_price_per_gib_minute/1, denomination/1,\n",
        "         height/1, kryder_plus_rate_multiplier/1]).\n",
        "-include_lib(\"arweave/include/ar.hrl\").\n",
        "price_per_gib_minute(B) -> B#block.price_per_gib_minute.\n",
        "scheduled_price_per_gib_minute(B) -> B#block.scheduled_price_per_gib_minute.\n",
        "denomination(B) -> B#block.denomination.\n",
        "height(B) -> B#block.height.\n",
        "kryder_plus_rate_multiplier(B) -> B#block.kryder_plus_rate_multiplier.\n"
    ]),
TmpDir = ".tmp/notebooks/",
ok = filelib:ensure_dir(filename:join([TmpDir, "keep"])),
AccessorPath = filename:join([TmpDir, "nb_block_accessors.erl"]),
ok = file:write_file(AccessorPath, AccessorModule),
{ok, nb_block_accessors, AccessorBin} = compile:file(AccessorPath, [binary]),
{module, nb_block_accessors} = code:load_binary(nb_block_accessors, AccessorPath, AccessorBin),

PricePerGiBMinute =
    fun(B) ->
        nb_block_accessors:price_per_gib_minute(B)
    end,
ScheduledPricePerGiBMinute =
    fun(B) ->
        nb_block_accessors:scheduled_price_per_gib_minute(B)
    end,
Denomination =
    fun(B) ->
        nb_block_accessors:denomination(B)
    end,
Height =
    fun(B) ->
        nb_block_accessors:height(B)
    end,
KryderPlusRateMultiplier =
    fun(B) ->
        nb_block_accessors:kryder_plus_rate_multiplier(B)
    end,

RPCCall =
    fun(Module, Function, Args) ->
        rpc:call(Node, Module, Function, Args)
    end,

RPCNodeGetHeight =
    fun() ->
        RPCCall(ar_node, get_height, [])
    end,

RPCPricingTransitionStart =
    fun() ->
        RPCCall(ar_pricing_transition, transition_start_2_7_2, [])
    end,

RPCPricingTransitionLength =
    fun() ->
        RPCCall(ar_pricing_transition, transition_length_2_7_2, [])
    end,

RPCPricingTransitionIsV2 =
    fun(HeightValue) ->
        RPCCall(ar_pricing_transition, is_v2_pricing_height, [HeightValue])
    end,

RPCBlockIndexGetByHeight =
    fun(HeightValue) ->
        RPCCall(ar_block_index, get_element_by_height, [HeightValue])
    end,

RPCBlockGet =
    fun(BlockHash) ->
        RPCCall(ar_storage, read_block, [BlockHash])
    end,

RPCPricingRecalculatePricePerGiBMinute =
    fun(Block) ->
        RPCCall(ar_pricing, recalculate_price_per_gib_minute, [Block])
    end,

RPCPricingRedenominate =
    fun(Value, FromDenomination, ToDenomination) ->
        RPCCall(ar_pricing, redenominate, [Value, FromDenomination, ToDenomination])
    end,

RPCPricingGetV2PricePerGiBMinute =
    fun(HeightValue, Block) ->
        RPCCall(ar_pricing, get_v2_price_per_gib_minute, [HeightValue, Block])
    end,

RPCWalletsGetChunk =
    fun(RootHash, Cursor) ->
        RPCCall(ar_wallets, get_chunk, [RootHash, Cursor])
    end,

RPCWalletsGet =
    fun(RootHash, Addr) ->
        RPCCall(ar_wallets, get, [RootHash, Addr])
    end,

RPCETSLookup =
    fun(Table, Key) ->
        RPCCall(ets, lookup, [Table, Key])
    end,

{ok, _} = application:ensure_all_started(inets),

HTTPGetBinary =
    fun(Url) ->
        case httpc:request(get, {Url, []}, [], []) of
            {ok, {{_, 200, _}, _Headers, Body}} ->
                {ok, Body};
            {ok, {{_, Status, _}, _Headers, Body}} ->
                {error, {http_status, Status, Body}};
            Error ->
                {error, Error}
        end
    end,

HTTPGetInteger =
    fun(Url) ->
        case HTTPGetBinary(Url) of
            {ok, Body} ->
                binary_to_integer(iolist_to_binary(Body));
            {error, Reason} ->
                {error, Reason}
        end
    end,

LocalnetHTTPHost =
    case os:getenv("LOCALNET_HTTP_HOST") of
        false ->
            "127.0.0.1";
        Value ->
            Value
    end,

LocalnetHTTPPort =
    case os:getenv("LOCALNET_HTTP_PORT") of
        false ->
            "1984";
        Value ->
            Value
    end,

ok.
# Out:
# ok

# %%
{net_adm:names('127.0.0.1'), node(), erlang:get_cookie()}.
# Out:
# {{ok,[{"erlang_1ePN0QVP",51755},
#       {"main-localnet",55436},
#       {"pricing_notebook",59029}]},
#  'pricing_notebook@127.0.0.1',localnet}

# %% [markdown]
# ## Connectivity check

# %%
{Node, net_adm:ping(Node)}.
# Out:
# {'main-localnet@127.0.0.1',pong}

# %%
RPCNodeGetHeight().
# Out:
# 1818163

# %% [markdown]
# ## Compute transition window

# %%
TransitionStart = RPCPricingTransitionStart(),
TransitionLength = RPCPricingTransitionLength(),
TransitionEnd = TransitionStart + TransitionLength,
StartHeight0 = TransitionEnd - 100,
StartHeight =
    case StartHeight0 < 0 of
        true ->
            0;
        false ->
            StartHeight0
    end,
StopHeight0 = TransitionEnd + 100,
CurrentHeight = RPCNodeGetHeight(),
StopHeight =
    case CurrentHeight < StopHeight0 of
        true ->
            CurrentHeight;
        false ->
            StopHeight0
    end,

#{
    transition_start => TransitionStart,
    transition_end => TransitionEnd,
    start_height => StartHeight,
    stop_height => StopHeight,
    current_height => CurrentHeight
}.
# Out:
# #{transition_start => 1551470,transition_end => 2069870,
#   start_height => 2069770,stop_height => 1818163,current_height => 1818163}

# %%
f(StartHeight), StartHeight = 1818150,
f(EndHeight), EndHeight = 1818160,
f(StopHeight), StopHeight = EndHeight.
# Out:
# 1818160

# %% [markdown]
# ## Fetch prices around transition end

# %%
GetBlock =
    fun(Height) ->
        BlockHash = RPCBlockIndexGetByHeight(Height),
        case RPCBlockGet(BlockHash) of
            not_found ->
                {error, {block_not_found, Height}};
            Block ->
                Block
        end
    end,

GetPriceInfo =
    fun(Height) ->
        case GetBlock(Height) of
            {error, _} = Error ->
                #{height => Height, error => Error};
            Block ->
                Price = PricePerGiBMinute(Block),
                Scheduled = ScheduledPricePerGiBMinute(Block),
                DenominationValue = Denomination(Block),
                #{height => Height, price => Price, scheduled_price => Scheduled,
                    denomination => DenominationValue}
        end
    end,

Heights = lists:seq(StartHeight, StopHeight),
Prices = [GetPriceInfo(Height) || Height <- Heights],
Prices.
# Out:
# [#{denomination => 1,height => 1818150,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818151,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818152,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818153,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818154,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818155,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818156,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818157,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818158,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818159,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818160,price => 1388,scheduled_price => 1390},
#  #{denomination => 1,height => 1818161,price => 1388,scheduled_price => 1390},
# ...

# %% [markdown]
# ## Validate price fields via recalc
#
# `price_per_gib_minute` already reflects v2 pricing with transition logic applied. We validate it directly and assert `/price` responses below.

# %%
ValidateHeight =
    fun(HeightValue) ->
        try
            case {GetBlock(HeightValue - 1), GetBlock(HeightValue)} of
                {{error, {block_not_found, _}}, _} ->
                    skip;
                {_, {error, {block_not_found, _}}} ->
                    skip;
                {{error, _} = Error, _} ->
                    {HeightValue, Error};
                {_, {error, _} = Error} ->
                    {HeightValue, Error};
                {PrevBlock, Block} ->
                    PrevDenomination = Denomination(PrevBlock),
                    DenominationValue = Denomination(Block),
                    Recalc = RPCPricingRecalculatePricePerGiBMinute(PrevBlock),
                    case Recalc of
                        {ExpectedPrice, ExpectedScheduled} ->
                            ExpectedPrice2 =
                                RPCPricingRedenominate(ExpectedPrice, PrevDenomination,
                                    DenominationValue),
                            ExpectedScheduled2 =
                                RPCPricingRedenominate(ExpectedScheduled, PrevDenomination,
                                    DenominationValue),
                            Price = PricePerGiBMinute(Block),
                            Scheduled = ScheduledPricePerGiBMinute(Block),
                            case {ExpectedPrice2 == Price, ExpectedScheduled2 == Scheduled} of
                                {true, true} ->
                                    ok;
                                _ ->
                                    {HeightValue, {price_mismatch, #{expected => ExpectedPrice2,
                                        actual => Price, expected_scheduled => ExpectedScheduled2,
                                        actual_scheduled => Scheduled}}}
                            end;
                        _ ->
                            {HeightValue, {recalc_failed, Recalc}}
                    end
            end
        catch
            Class:Reason ->
                {HeightValue, {validation_failed, {Class, Reason}}}
        end
    end,

Checks = [ValidateHeight(HeightValue) || HeightValue <- lists:seq(StartHeight + 1, StopHeight)],
Failures = [Check || Check <- Checks, Check =/= ok, Check =/= skip],
case Failures of
    [] ->
        ok;
    _ ->
        Failures
end.
# Out:
# [{1818151,{validation_failed,{error,{badmatch,1}}}},
#  {1818152,{validation_failed,{error,{badmatch,1}}}},
#  {1818153,{validation_failed,{error,{badmatch,1}}}},
#  {1818154,{validation_failed,{error,{badmatch,1}}}},
#  {1818155,{validation_failed,{error,{badmatch,1}}}},
#  {1818156,{validation_failed,{error,{badmatch,1}}}},
#  {1818157,{validation_failed,{error,{badmatch,1}}}},
#  {1818158,{validation_failed,{error,{badmatch,1}}}},
#  {1818159,{validation_failed,{error,{badmatch,1}}}},
#  {1818160,{validation_failed,{error,{badmatch,1}}}},
#  {1818161,{validation_failed,{error,{badmatch,1}}}},
#  {1818162,{validation_failed,{error,{badmatch,1}}}},
#  {1818163,{validation_failed,{error,{badmatch,1}}}}]

# %% [markdown]
# ## Validate /price endpoints

# %%
NodeStateValue =
    fun(Key) ->
        case RPCETSLookup(node_state, Key) of
            [{Key, Value}] ->
                Value;
            [] ->
                undefined;
            Other ->
                {error, {unexpected_node_state_lookup, {Key, Other}}}
        end
    end,

GiB = 1024 * 1024 * 1024,
HeightValue = RPCNodeGetHeight(),
CurrentPriceValue = NodeStateValue(price_per_gib_minute),
ScheduledPriceValue = NodeStateValue(scheduled_price_per_gib_minute),
KryderPlusRateValue = NodeStateValue(kryder_plus_rate_multiplier),
WalletRoot = NodeStateValue(wallet_list),

case {CurrentPriceValue, ScheduledPriceValue,
    KryderPlusRateValue, WalletRoot} of
    {Price, Scheduled, KryderPlus, RootHash}
        when is_integer(Price), is_integer(Scheduled), is_integer(KryderPlus),
            is_binary(RootHash) ->
        case RPCWalletsGetChunk(RootHash, first) of
            {ok, {_NextCursor, WalletRange}} when is_list(WalletRange) ->
                case WalletRange of
                    [First | _] ->
                        Addr =
                            case First of
                                {AddrValue, _Wallet} when is_binary(AddrValue) ->
                                    AddrValue;
                                AddrValue when is_binary(AddrValue) ->
                                    AddrValue;
                                _ ->
                                    {error, {unexpected_wallet_entry, First}}
                            end,
                        case Addr of
                            {error, _} = Error ->
                                Error;
                            _ ->
                                AddrBase64 =
                                    ar_wallet:decoded_address_to_base64_address_with_checksum(Addr),
                                Accounts0 = RPCWalletsGet(RootHash, Addr),
                                case Accounts0 of
                                    Accounts when is_map(Accounts) ->
                                        try
                                            Size2 =
                                                ar_tx:get_weave_size_increase(GiB, HeightValue + 1),
                                            PricePerGiBMinuteValue = max(Price, Scheduled),
                                            ArgsNoAddr =
                                                {Size2, PricePerGiBMinuteValue, KryderPlus, <<>>, #{},
                                                    HeightValue + 1},
                                            ExpectedFeeNoAddr = ar_tx:get_tx_fee(ArgsNoAddr),
                                            ArgsWithAddr =
                                                {Size2, PricePerGiBMinuteValue, KryderPlus, Addr,
                                                    Accounts, HeightValue + 1},
                                            ExpectedFeeWithAddr = ar_tx:get_tx_fee(ArgsWithAddr),
                                            BaseUrl =
                                                "http://" ++ LocalnetHTTPHost ++ ":" ++ LocalnetHTTPPort,
                                            PriceUrl =
                                                BaseUrl ++ "/price/" ++ integer_to_list(GiB),
                                            PriceAddrUrl =
                                                PriceUrl ++ "/" ++ binary_to_list(AddrBase64),
                                            case {HTTPGetInteger(PriceUrl),
                                                HTTPGetInteger(PriceAddrUrl)} of
                                                {{error, Reason}, _} ->
                                                    {error, {price_request_failed, Reason}};
                                                {_, {error, Reason}} ->
                                                    {error, {price_addr_request_failed, Reason}};
                                                {FeeNoAddr, FeeWithAddr} ->
                                                    case {FeeNoAddr == ExpectedFeeNoAddr,
                                                        FeeWithAddr == ExpectedFeeWithAddr} of
                                                        {true, true} ->
                                                            ok;
                                                        _ ->
                                                            {price_mismatch, #{
                                                                expected_no_addr => ExpectedFeeNoAddr,
                                                                actual_no_addr => FeeNoAddr,
                                                                expected_with_addr => ExpectedFeeWithAddr,
                                                                actual_with_addr => FeeWithAddr
                                                            }}
                                                    end
                                            end
                                        catch
                                            Class:Reason ->
                                                {error, {price_calc_failed, {Class, Reason}}}
                                        end;
                                    Other ->
                                        {error, {wallet_accounts_unexpected, Other}}
                                end
                        end;
                    [] ->
                        {error, no_wallets}
                end;
            {ok, Other} ->
                {error, {wallet_range_unexpected, Other}};
            Error ->
                {error, {wallet_lookup_failed, Error}}
        end;
    _ ->
        {error, {missing_node_state, #{
            price_per_gib_minute => CurrentPriceValue,
            scheduled_price_per_gib_minute => ScheduledPriceValue,
            kryder_plus_rate_multiplier => KryderPlusRateValue,
            wallet_list => WalletRoot
        }}}
end.

# %% [markdown]
# ## Validate v2 pricing post-transition

# %%
ValidateV2 =
    fun(HeightValue) ->
        case RPCPricingTransitionIsV2(HeightValue) of
            true ->
                case GetBlock(HeightValue) of
                    {error, {block_not_found, _}} ->
                        skip;
                    {error, _} = Error ->
                        {HeightValue, Error};
                    Block ->
                        Price = PricePerGiBMinute(Block),
                        V2Price = RPCPricingGetV2PricePerGiBMinute(HeightValue, Block),
                        case Price == V2Price of
                            true ->
                                ok;
                            false ->
                                {HeightValue, {v2_price_mismatch, #{expected => V2Price,
                                    actual => Price}}}
                        end
                end;
            false ->
                ok
        end
    end,

V2Checks = [ValidateV2(HeightValue) || HeightValue <- lists:seq(StartHeight, StopHeight)],
V2Failures = [Check || Check <- V2Checks, Check =/= ok, Check =/= skip],
case V2Failures of
    [] ->
        ok;
    _ ->
        V2Failures
end.
# Out:
# ok

# %% [markdown]
# ## Plot per-GiB fees

# %% [markdown]
# Python plot output below (writes PNG in `.tmp/notebooks`).

# %%
GiB = 1024 * 1024 * 1024,

FeeForPrice =
    fun(Block, PricePerGiBMinuteValue) ->
        BlockHeight = Height(Block),
        KryderPlus = KryderPlusRateMultiplier(Block),
        Size2 = ar_tx:get_weave_size_increase(GiB, BlockHeight + 1),
        Args = {Size2, PricePerGiBMinuteValue, KryderPlus, <<>>, #{}, BlockHeight + 1},
        ar_tx:get_tx_fee(Args)
    end,

FeeRows =
    lists:map(
        fun(RowHeight) ->
            case GetBlock(RowHeight) of
                {error, _} = Error ->
                    #{height => RowHeight, error => Error};
                Block ->
                    CurrentFee = FeeForPrice(Block, PricePerGiBMinute(Block)),
                    ScheduledFee = FeeForPrice(Block, ScheduledPricePerGiBMinute(Block)),
                    #{height => RowHeight, current_fee => CurrentFee, scheduled_fee => ScheduledFee}
            end
        end,
        lists:seq(StartHeight, StopHeight)
    ),

FeeRowsFiltered =
    lists:foldl(
        fun(Row, Acc) ->
            case Row of
                #{height := RowHeight, current_fee := RowCurrentFee,
                    scheduled_fee := RowScheduledFee} ->
                    [#{height => RowHeight, current_fee => RowCurrentFee,
                        scheduled_fee => RowScheduledFee} | Acc];
                _ ->
                    Acc
            end
        end,
        [],
        FeeRows
    ),
FeeRowsFilteredRev = lists:reverse(FeeRowsFiltered),

CSVPath = ".tmp/notebooks/pricing_fees.csv",
ok = filelib:ensure_dir(CSVPath),
CSVLines =
    ["height,current_fee,scheduled_fee\n"] ++
    [lists:flatten(io_lib:format("~p,~p,~p\n", [RowHeight, RowCurrentFee,
        RowScheduledFee]))
        || #{height := RowHeight, current_fee := RowCurrentFee,
            scheduled_fee := RowScheduledFee} <- FeeRowsFilteredRev],
ok = file:write_file(CSVPath, CSVLines),

PlotPath = ".tmp/notebooks/pricing_fees.png",
ScriptPath = ".tmp/notebooks/plot_pricing_fees.py",
PythonScript =
    lists:flatten([
        "from pathlib import Path\n",
        "import csv\n",
        "import matplotlib.pyplot as plt\n",
        "csv_path = Path('", CSVPath, "')\n",
        "out_path = Path('", PlotPath, "')\n",
        "heights = []\n",
        "current = []\n",
        "scheduled = []\n",
        "with csv_path.open() as f:\n",
        "    reader = csv.DictReader(f)\n",
        "    for row in reader:\n",
        "        heights.append(int(row['height']))\n",
        "        current.append(int(row['current_fee']))\n",
        "        scheduled.append(int(row['scheduled_fee']))\n",
        "plt.figure(figsize=(10, 4))\n",
        "plt.plot(heights, current, label='current')\n",
        "plt.plot(heights, scheduled, label='scheduled')\n",
        "plt.xlabel('height')\n",
        "plt.ylabel('fee')\n",
        "plt.legend()\n",
        "plt.tight_layout()\n",
        "out_path.parent.mkdir(parents=True, exist_ok=True)\n",
        "plt.savefig(out_path)\n"
    ]),
ok = filelib:ensure_dir(ScriptPath),
ok = file:write_file(ScriptPath, PythonScript),

SkipPlot =
    case os:getenv("NOTEBOOK_SKIP_PLOT") of
        "1" ->
            true;
        "true" ->
            true;
        "yes" ->
            true;
        _ ->
            false
    end,

PlotOutput =
    case SkipPlot of
        true ->
            "skipped";
        false ->
            os:cmd("uv run python " ++ ScriptPath)
    end,

#{fees => FeeRows, csv => CSVPath, plot => PlotPath, python_output => PlotOutput}.
# Out:
# #{fees =>
#       [#{height => 1818150,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818151,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818152,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818153,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818154,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818155,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818156,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818157,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818158,current_fee => 3056380403339,
#          scheduled_fee => 3060784409684},
#        #{height => 1818159,current_fee => 3056380403339,
# ...
